# %% [markdown]
# ## **1(a)**

# %% [markdown]
# **Softmax Function :**
#
# Softmax function is used as an activation fuction in output layers.Cross enthropy function is used in the softmax funtion.It keeps he values between 0 and 1 for activation.Morevover, sum of these values will be 1.
# Formula for softmax function can be given as
# </br>
# </br>
#
# $ p_{k} = \frac{e^{fk}}{\sum_{j}^{}e^{fC}}$
# </br>
# </br>
#
# **Negative Log-Likelyhood (NLL):**
#
# The loss grows larger on every incorrect prediction, since the determined loss will be zero at that prediction and we sum the loss for all the correct predictions.Hence to optimize a loss function, NLL finds the local minima of that loss fucntion. It is inversely proportional to the no. of values. Negative Log-Likelyhood can be given as follows.
# </br>
# </br>
# $L_{y} = -log({y_{i}})$

# %% [markdown]
# ## **1(b)**

# %% [markdown]
# Suppose we are predicting a single continuous target variable t from
# a vector x of inputs (the extension to multiple targets is straightforward). We shall
# suppose that the conditional distribution p(t|x) is Gaussian, with an x-dependent
# mean given by the output of a neural network model y(x,w), and with precision
# (inverse variance) β
# </br>
# </br>
# p(t|x,w, β) = N(t|y(x,w), β
# −1).
# </br>
# </br>
# Similarly, we shall choose a prior distribution over the weights w that is Gaussian of the form
# </br>
# </br>
# p(w|α) = N(w|0, α−1I).
# </br>
# </br>
# For an i.i.d. data set of N observations x1, . . . , xN, with a corresponding set of target
# values D = {t1, . . . , tN}, the likelihood function is given by
# </br>
# </br>
#
#
# p(D|w, β) =$\prod$ n=1
# N(tn|y(xn,w), β
# −1)
# </br>
# </br>
# and so the resulting posterior distribution is then
# </br>
# </br>
# p(w|D, α, β) ∝ p(w|α)p(D|w, β). (5.164)
# </br>
# </br>
# which, as a consequence of the nonlinear dependence of y(x,w) on w, will be non-
# Gaussian.
# We can find a Gaussian approximation to the posterior distribution by using the
# Laplace approximation. To do this, we must first find a (local) maximum of the
# posterior, and this must be done using iterative numerical optimization. As usual, it
# is convenient to maximize the logarithm of the posterior, which can be written in the form
# </br>
# </br>
#
# ln p(w|D) = −α/2 wTw − β/2$\sum_{n=1}^{N}$n=1{y(xn,w) − tn}^2 + const
# </br>
# </br>
# which corresponds to a regularized sum-of-squares error function. Assuming for
# the moment that α and β are fixed, we can find a maximum of the posterior, which
# we denote wMAP, by standard nonlinear optimization algorithms such as conjugate
# gradients, using error backpropagation to evaluate the required derivatives.

# %% [markdown]
# # **2(a), 2(b), 2(c)**

# %%
# Importing utility libraries

import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import LambdaCallback
from keras import regularizers
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
# Splitting the dataset
(X_train, y_train),(X_test, y_test ) = mnist.load_data()
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((60000, 28, 28), (10000, 28, 28), (60000,), (10000,))

# %%
for i in range(25):
    plt.subplot(5,5, i+1)
    plt.imshow(X_train[i], cmap = 'gray_r')
plt.show()

# %%
image_shape = (28, 28, 1)
def func_discriminator (image_shape()):
  model = Sequential()
  model.add(Conv2D(128, (3,3), strides=(2,2), padding='same', input_shape=in_shape))
	model.add(LeakyReLU(alpha=0.2))
	# downsample
	model.add(Conv2D(128, (3,3), strides=(2,2), padding='same'))
	model.add(LeakyReLU(alpha=0.2))
	# classifier
	model.add(Flatten())
	model.add(Dropout(0.4))
	model.add(Dense(1, activation='sigmoid'))
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])
	return model      


# # Making the 1000 image dataset for model
# CLASSES = 10
# IMAGES = 100
# image_1k = []
# label_1k = []
# data= dict()

# data = {i: [] for i in range(CLASSES)}


# for i in range(len(X_train)):
#     data[y_train[i]].append(X_train[i])
   

# for i in range(len(data)):
#     for j in range(IMAGES):
#         image_1k.append(data[i][j])
#         label_1k.append(i)

# image_1k = np.asarray(image_1k)
# label_1k = np.asarray(label_1k)

# image_1k.shape, label_1k.shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-51ac1837037c> in <module>()
#      23 # image_1k.shape, label_1k.shape
#      24
# ---> 25 plt.imshow(X_train[:10],cmap='gray')
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2649         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2650         resample=resample, url=url, **({"data": data} if data is not
# -> 2651         None else {}), **kwargs)
#    2652     sci(__ret)
#    2653     return __ret
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# ...

# %% [markdown]
# ## Neural Network With 1 Hidden Layer

# %%
 print(X_train.shape)
# Out:
# (50000, 28, 28)

# %%
# Defining model with 1 hidden layers

def model () :

    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid))
    model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
    opt = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])
    
    # Getting weights to calculate learning rate
    weights_nn = {}
    callback  = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: weights_nn.update({epoch:model.get_weights()})) 
    history_1 = model.fit(image_1k, label_1k, validation_data = (X_val, y_val), epochs = 30, batch_size = 10, callbacks = callback)

    # evaluating model   
    loss, accuracy = model.evaluate(X_test, y_test)
    print('')
    print('Accuracy % of 1 Layer Model with Regularization:', accuracy*100)
    print('')
    print('Loss  %  on 1 Layer Model with Regularization:', (1-accuracy)*100)
    print('')
    print("weights",weights_nn[0][0])
    print('')
    
    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(history_1.history['loss'])
    plt.plot(history_1.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(history_1.history['accuracy'])
    plt.plot(history_1.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()

model()
# Out:
# Epoch 1/30
# 100/100 [==============================] - 5s 17ms/step - loss: 2.2716 - accuracy: 0.1693 - val_loss: 1.9360 - val_accuracy: 0.3002
# Epoch 2/30
# 100/100 [==============================] - 1s 13ms/step - loss: 1.9162 - accuracy: 0.3068 - val_loss: 1.8016 - val_accuracy: 0.3726
# Epoch 3/30
# 100/100 [==============================] - 1s 13ms/step - loss: 1.8037 - accuracy: 0.3180 - val_loss: 1.7191 - val_accuracy: 0.4042
# Epoch 4/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.6719 - accuracy: 0.4476 - val_loss: 1.6056 - val_accuracy: 0.4616
# Epoch 5/30
# 100/100 [==============================] - 1s 13ms/step - loss: 1.6158 - accuracy: 0.4311 - val_loss: 1.7334 - val_accuracy: 0.3277
# Epoch 6/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.6876 - accuracy: 0.3292 - val_loss: 1.6070 - val_accuracy: 0.4330
# Epoch 7/30
# ...

# %% [markdown]
# ## Neural Network With 2 Hidden Layers

# %%
# Defining model with 2 hidden layers

def model_2 () :
  
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid))
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid))
    model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
    opt = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])
    
    weights_nn = {}
    callback  = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: weights_nn.update({epoch:model.get_weights()})) 
    history_2 = model.fit(image_1k, label_1k, validation_data = (X_val, y_val), epochs = 30, batch_size = 10, callbacks = callback)

    # evaluating model   
    loss, accuracy = model.evaluate(X_test, y_test)
    print('')
    print('Accuracy % of 1 Layer Model with Regularization:', accuracy*100)
    print('')
    print('Loss  %  on 1 Layer Model with Regularization:', (1-accuracy)*100)
    print('')
    print("weights",weights_nn[0][0])
    print('')

    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(history_2.history['loss'])
    plt.plot(history_2.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(history_2.history['accuracy'])
    plt.plot(history_2.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()
      
model_2()
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 15ms/step - loss: 2.3444 - accuracy: 0.1381 - val_loss: 2.0113 - val_accuracy: 0.2866
# Epoch 2/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.9768 - accuracy: 0.2621 - val_loss: 1.8682 - val_accuracy: 0.2953
# Epoch 3/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7871 - accuracy: 0.3303 - val_loss: 1.7106 - val_accuracy: 0.3674
# Epoch 4/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7650 - accuracy: 0.3470 - val_loss: 1.6665 - val_accuracy: 0.3895
# Epoch 5/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.7148 - accuracy: 0.3658 - val_loss: 1.6457 - val_accuracy: 0.4271
# Epoch 6/30
# 100/100 [==============================] - 1s 14ms/step - loss: 1.6749 - accuracy: 0.3687 - val_loss: 1.6077 - val_accuracy: 0.3942
# Epoch 7/30
# ...

# %% [markdown]
# ## Neural Network With 3 Hidden Layers

# %%
def model_3 () :
  
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid))
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid))
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid))
    model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
    opt = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])

    weights_nn = {}
    callback  = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: weights_nn.update({epoch:model.get_weights()})) 
    history_3 = model.fit(image_1k, label_1k, validation_data = (X_val, y_val), epochs = 30, batch_size = 10, callbacks = callback)

    # evaluating model   
    loss, accuracy = model.evaluate(X_test, y_test)
    print('')
    print('Accuracy % of 1 Layer Model with Regularization:', accuracy*100)
    print('')
    print('Loss  %  on 1 Layer Model with Regularization:', (1-accuracy)*100)
    print('')
    print("weights",weights_nn[0][0])
    print('')

    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(history_3.history['loss'])
    plt.plot(history_3.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(history_3.history['accuracy'])
    plt.plot(history_3.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()
      

model_3()
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 15ms/step - loss: 2.3867 - accuracy: 0.0859 - val_loss: 2.3042 - val_accuracy: 0.0967
# Epoch 2/30
# 100/100 [==============================] - 1s 14ms/step - loss: 2.3213 - accuracy: 0.1135 - val_loss: 2.2767 - val_accuracy: 0.1395
# Epoch 3/30
# 100/100 [==============================] - 1s 14ms/step - loss: 2.2703 - accuracy: 0.1485 - val_loss: 2.2626 - val_accuracy: 0.2292
# Epoch 4/30
# 100/100 [==============================] - 1s 14ms/step - loss: 2.2654 - accuracy: 0.1664 - val_loss: 2.2152 - val_accuracy: 0.1496
# Epoch 5/30
# 100/100 [==============================] - 1s 14ms/step - loss: 2.1739 - accuracy: 0.1723 - val_loss: 2.2046 - val_accuracy: 0.1742
# Epoch 6/30
# 100/100 [==============================] - 1s 14ms/step - loss: 2.2225 - accuracy: 0.1287 - val_loss: 2.1590 - val_accuracy: 0.1741
# Epoch 7/30
# ...

# %% [markdown]
# ## Neural Network With 1 Hidden Layer and Regularization

# %%
def model_4 () :
  
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid, kernel_regularizer = regularizers.l2(5)))
    model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
    opt = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])
    
    # Getting weights to calculate learning rate
    weights_nn = {}
    callback  = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: weights_nn.update({epoch:model.get_weights()}))
    
    history_4 = model.fit(image_1k, label_1k, validation_data = (X_val, y_val), epochs = 30, batch_size = 10, callbacks=callback )
   

    # evaluating model
    loss, accuracy = model.evaluate(X_test, y_test)
    print('')
    print('Accuracy % of 1 Layer Model with Regularization:', accuracy*100)
    print('')
    print('Loss  %  on 1 Layer Model with Regularization:', (1-accuracy)*100)
    print('')
    print("weights",weights_nn[0][0])
    print('')

    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(history_4.history['loss'])
    plt.plot(history_4.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(history_4.history['accuracy'])
    plt.plot(history_4.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()
      


model_4()
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 16ms/step - loss: 44.9743 - accuracy: 0.1168 - val_loss: 5.7046 - val_accuracy: 0.1393
# Epoch 2/30
# 100/100 [==============================] - 1s 14ms/step - loss: 5.4788 - accuracy: 0.1026 - val_loss: 5.1445 - val_accuracy: 0.0915
# Epoch 3/30
# 100/100 [==============================] - 1s 14ms/step - loss: 5.4496 - accuracy: 0.1267 - val_loss: 5.0943 - val_accuracy: 0.0712
# Epoch 4/30
# 100/100 [==============================] - 1s 14ms/step - loss: 5.1854 - accuracy: 0.1174 - val_loss: 5.1391 - val_accuracy: 0.1905
# Epoch 5/30
# 100/100 [==============================] - 1s 14ms/step - loss: 5.0701 - accuracy: 0.1129 - val_loss: 5.5786 - val_accuracy: 0.1354
# Epoch 6/30
# 100/100 [==============================] - 1s 14ms/step - loss: 5.2920 - accuracy: 0.0906 - val_loss: 5.0372 - val_accuracy: 0.1185
# Epoch 7/30
# ...

# %% [markdown]
# ## Neural Network With 2 Hidden Layer and Regularization

# %%
def model_5 () :
  
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid, kernel_regularizer = regularizers.l2(5)))
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid, kernel_regularizer = regularizers.l2(5)))
    model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
    opt = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])

    weights_nn = {}
    callback  = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: weights_nn.update({epoch:model.get_weights()})) 
    history_5 = model.fit(image_1k, label_1k, validation_data = (X_val, y_val), epochs = 30, batch_size = 10, callbacks = callback)

    # evaluating model   
    loss, accuracy = model.evaluate(X_test, y_test)
    print('')
    print('Accuracy % of 1 Layer Model with Regularization:', accuracy*100)
    print('')
    print('Loss  %  on 1 Layer Model with Regularization:', (1-accuracy)*100)
    print('')
    print("weights",weights_nn[0][0])
    print('')

    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(history_5.history['loss'])
    plt.plot(history_5.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(history_5.history['accuracy'])
    plt.plot(history_5.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()
      

model_5()
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 16ms/step - loss: 85.4412 - accuracy: 0.1122 - val_loss: 2.3482 - val_accuracy: 0.0983
# Epoch 2/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3312 - accuracy: 0.0906 - val_loss: 2.3248 - val_accuracy: 0.1030
# Epoch 3/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3423 - accuracy: 0.0868 - val_loss: 2.3308 - val_accuracy: 0.1009
# Epoch 4/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3354 - accuracy: 0.1025 - val_loss: 2.3330 - val_accuracy: 0.1064
# Epoch 5/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3355 - accuracy: 0.1108 - val_loss: 2.3153 - val_accuracy: 0.1009
# Epoch 6/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3376 - accuracy: 0.1027 - val_loss: 2.3495 - val_accuracy: 0.0990
# Epoch 7/30
# ...

# %% [markdown]
# ## Neural Network With 3 Hidden Layer and Regularization

# %%
def model_6 () :
  
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten())
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid, kernel_regularizer = regularizers.l2(5)))
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid, kernel_regularizer = regularizers.l2(5)))
    model.add(tf.keras.layers.Dense(30, activation=tf.sigmoid, kernel_regularizer = regularizers.l2(5)))
    model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))
    opt = tf.keras.optimizers.Adam(lr=0.01)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])

    weights_nn = {}
    callback  = tf.keras.callbacks.LambdaCallback(on_epoch_end=lambda epoch, logs: weights_nn.update({epoch:model.get_weights()})) 
    history_6 = model.fit(image_1k, label_1k, validation_data = (X_val, y_val), epochs = 30, batch_size = 10, callbacks = callback)

    # evaluating model   
    loss, accuracy = model.evaluate(X_test, y_test)
    print('')
    print('Accuracy % of 1 Layer Model with Regularization:', accuracy*100)
    print('')
    print('Loss  %  on 1 Layer Model with Regularization:', (1-accuracy)*100)
    print('')
    print("weights",weights_nn[0][0])
    print('')

    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(history_6.history['loss'])
    plt.plot(history_6.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(history_6.history['accuracy'])
    plt.plot(history_6.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()
      

model_6()
# Out:
# Epoch 1/30
# 100/100 [==============================] - 2s 17ms/step - loss: 126.3070 - accuracy: 0.0812 - val_loss: 2.3455 - val_accuracy: 0.1064
# Epoch 2/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3456 - accuracy: 0.1055 - val_loss: 2.3300 - val_accuracy: 0.1009
# Epoch 3/30
# 100/100 [==============================] - 2s 15ms/step - loss: 2.3473 - accuracy: 0.0976 - val_loss: 2.3360 - val_accuracy: 0.1064
# Epoch 4/30
# 100/100 [==============================] - 2s 15ms/step - loss: 2.3264 - accuracy: 0.1161 - val_loss: 2.3248 - val_accuracy: 0.1090
# Epoch 5/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3307 - accuracy: 0.0937 - val_loss: 2.3332 - val_accuracy: 0.0967
# Epoch 6/30
# 100/100 [==============================] - 1s 15ms/step - loss: 2.3372 - accuracy: 0.0955 - val_loss: 2.3238 - val_accuracy: 0.0990
# Epoch 7/30
# ...

# %% [markdown]
# ## CNN and Data Augmentation

# %%
# Normalizing the data for CNN
X_test = X_test.reshape(X_test.shape[0], 28, 28, 1)
X_val = X_val.reshape(X_val.shape[0], 28, 28, 1)
image_1k = image_1k.reshape(image_1k.shape[0], 28, 28, 1)

# %%
def model_cnn():
 
    model = tf.keras.models.Sequential([
            tf.keras.layers.Conv2D(32, kernel_size=(5,5), strides=(1,1), activation='relu', input_shape=(28,28,1)),
            tf.keras.layers.MaxPooling2D(pool_size=(2,2), strides=(2,2)),
            tf.keras.layers.Conv2D(64, kernel_size=(5,5), activation='relu'),
            tf.keras.layers.MaxPooling2D(pool_size=(2,2)),
            tf.keras.layers.Dropout(0.2),
            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(1000, activation='relu'),
            tf.keras.layers.Dense(10, activation='softmax')])
    opt = tf.keras.optimizers.Adam(lr=0.1)
    model.compile(optimizer = opt, loss='sparse_categorical_crossentropy',  metrics=['accuracy'])
    
    datagen =ImageDataGenerator(
        featurewise_center=True,
        samplewise_center=True,
        rotation_range=3,
        width_shift_range=3.0,
        height_shift_range=3.0,
        horizontal_flip=True,
        vertical_flip=True)
    
    cnn_history = model.fit_generator(datagen.flow(image_1k,label_1k,batch_size =10),
                                      validation_data =(X_val,y_val) ,             
                                      steps_per_epoch = len(image_1k)/10, 
                                      epochs= 10)
        
    cnn_loss, cnn_accuracy = model.evaluate(X_test,y_test)

    print('')
    print('Accuracy of CNN Model With Data Augmentation:', cnn_accuracy*100)
    print('')
    print('Loss of CNN Model With Data Augmentation:', (1-cnn_accuracy)*100)
    print('')

    # Plotting Criterion Funtion
    plt.figure(figsize=(8,5))
    plt.plot(cnn_history.history['loss'])
    plt.plot(cnn_history.history['val_loss'])
    plt.title('Criterion Function')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend(['Training loss', 'Validation Loss'], loc='upper right')
    plt.show()
    
    # Plotting Accuracy Plot
    plt.figure(figsize=(8,5))
    plt.plot(cnn_history.history['accuracy'])
    plt.plot(cnn_history.history['val_accuracy'])
    plt.title('Model Accuracy')
    plt.ylabel('Accuracy')
    plt.xlabel('Epochs')
    plt.legend(['Train', 'Test'], loc='upper right')
    plt.show()


model_cnn()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/10
# 100/100 [==============================] - 31s 14ms/step - loss: 110849.2568 - accuracy: 0.0937 - val_loss: 401612.3125 - val_accuracy: 0.1420
# Epoch 2/10
# 100/100 [==============================] - 1s 12ms/step - loss: 2.3250 - accuracy: 0.0894 - val_loss: 401701.7812 - val_accuracy: 0.1331
# Epoch 3/10
# ...
